# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\HP\\Sravani\\synthetic_credit_card_transactions.csv')

# %%
# Check the first few rows
df.head()
# Out:
#    Transaction_ID Card_Type Transaction_Date Merchant_Category  Amount  \
# 0           10001      Amex       2024-10-13             Books  144.76
# 1           10002      Visa       2024-07-31       Electronics   24.60
# 2           10003      Amex       2024-04-15             Books  353.65
# 3           10004      Visa       2024-07-27          Clothing  176.72
# 4           10005      Visa       2024-09-20       Electronics  185.90
#
#   Transaction_Type       Location Fraudulent_Flag Merchant_ID
# 0         Purchase        Chicago              No       M9935
# 1         Purchase  San Francisco              No       M1434
# 2           Refund  San Francisco              No       M5557
# 3         Purchase  San Francisco              No       M6514
# 4           Refund         Dallas              No       M1711

# %%
df.tail() #last few rows
# Out:
#       Transaction_ID   Card_Type Transaction_Date Merchant_Category  Amount  \
# 9995           19996  MasterCard       2024-03-12          Clothing   34.20
# 9996           19997        Visa       2024-09-12             Books  374.74
# 9997           19998        Visa       2024-06-27        Restaurant  240.06
# 9998           19999  MasterCard       2024-10-14              Toys  208.55
# 9999           20000  MasterCard       2024-03-06         Groceries  247.82
#
#      Transaction_Type Location Fraudulent_Flag Merchant_ID
# 9995           Refund   Dallas              No       M5957
# 9996         Purchase    Miami              No       M4264
# 9997           Refund  Houston              No       M6396
# 9998         Purchase   Austin              No       M5772
# 9999           Refund  Houston              No       M4010

# %%
df. #(Rows,Columns)
# Out:
# (10000, 9)

# %%
df.info() #Information about the file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Transaction_ID     10000 non-null  int64
#  1   Card_Type          10000 non-null  object
#  2   Transaction_Date   10000 non-null  object
#  3   Merchant_Category  10000 non-null  object
#  4   Amount             10000 non-null  float64
#  5   Transaction_Type   10000 non-null  object
#  6   Location           10000 non-null  object
#  7   Fraudulent_Flag    10000 non-null  object
#  8   Merchant_ID        10000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 703.3+ KB

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Transaction_ID       0
# Card_Type            0
# Transaction_Date     0
# Merchant_Category    0
# Amount               0
# Transaction_Type     0
# Location             0
# Fraudulent_Flag      0
# Merchant_ID          0
# dtype: int64

# %%
df.describe()
# Out:
#        Transaction_ID        Amount
# count     10000.00000  10000.000000
# mean      15000.50000    253.052972
# std        2886.89568    141.809346
# min       10001.00000     10.050000
# 25%       12500.75000    130.470000
# 50%       15000.50000    252.445000
# 75%       17500.25000    376.605000
# max       20000.00000    499.810000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Transaction_ID     10000 non-null  int64
#  1   Card_Type          10000 non-null  object
#  2   Transaction_Date   10000 non-null  object
#  3   Merchant_Category  10000 non-null  object
#  4   Amount             10000 non-null  float64
#  5   Transaction_Type   10000 non-null  object
#  6   Location           10000 non-null  object
#  7   Fraudulent_Flag    10000 non-null  object
#  8   Merchant_ID        10000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 703.3+ KB

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'],format='%d/%m/%Y',errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Transaction_ID     10000 non-null  int64
#  1   Card_Type          10000 non-null  object
#  2   Transaction_Date   0 non-null      datetime64[ns]
#  3   Merchant_Category  10000 non-null  object
#  4   Amount             10000 non-null  float64
#  5   Transaction_Type   10000 non-null  object
#  6   Location           10000 non-null  object
#  7   Fraudulent_Flag    10000 non-null  object
#  8   Merchant_ID        10000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 703.3+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df['Location'] = df['Location'].str.upper() # Standardize location as uppercase
df.head()
# Out:
#    Transaction_ID Card_Type Transaction_Date Merchant_Category  Amount  \
# 0           10001      Amex              NaT             Books  144.76
# 1           10002      Visa              NaT       Electronics   24.60
# 2           10003      Amex              NaT             Books  353.65
# 3           10004      Visa              NaT          Clothing  176.72
# 4           10005      Visa              NaT       Electronics  185.90
#
#   Transaction_Type       Location Fraudulent_Flag Merchant_ID
# 0         Purchase        CHICAGO              No       M9935
# 1         Purchase  SAN FRANCISCO              No       M1434
# 2           Refund  SAN FRANCISCO              No       M5557
# 3         Purchase  SAN FRANCISCO              No       M6514
# 4           Refund         DALLAS              No       M1711

# %%
#Check for Unique Values:
print(len(df))
print(df['Transaction_ID'].nunique())
# Out:
# 10000
# 10000

# %%
#Check for Unique Values:
print(len(df))
print(df['Merchant_ID'].nunique())
# Out:
# 10000
# 6083

# %%
# Create a histogram for age distribution
plt.figure(figsize=(14, 8))
sns.histplot(df['Location'], bins=df['Merchant_Category'],kde=True,color='blue', edgecolor='black')

# Add titles and labels
plt.title('Credit card Transactions')
plt.xlabel('Locations')
plt.ylabel('Types of products purchased')
plt.savefig("C:\\Users\\HP\\Downloads\\one.png") #to save pie chart in desired location
#plt.tight_layout()  # Adjust layout
plt.show()

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Plot the boxplot again without the outliers, without using palette
plt.figure(figsize=(8, 6))
sns.boxplot(x='Amount', y='Card_Type', data=df_filtered)

# Set the title and labels
plt.title('Box Plot of Amount Paid (Without Outliers)')
plt.xlabel('Amount')
plt.savefig("C:\\Users\\HP\\Downloads\\two.png") #to save pie chart in desired location
# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Merchant_Category'], bins=2)
plt.title('Distribution of Merchant_Category ')
plt.xlabel('Products sold')
plt.ylabel('Count')
plt.show()

# %%
# Group by country and count the number of athletes
product_counts = df.groupby('Location')['Merchant_Category'].count().reset_index()
product_counts.columns = ['Locations', 'Types of products']

# Get the top 50 countries by athlete count
top_50_countries = product_counts.nlargest(50, 'Types of products')

# Create a bar chart for the top 50 countries
plt.figure(figsize=(12, 8))
plt.bar(top_50_countries['Locations'], top_50_countries['Types of products'], color='skyblue')
plt.title('Top 50 Countries based produts')
plt.xlabel('Country')
plt.ylabel('Number of products')
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.tight_layout()  # Adjust layout
plt.show()

# %%
import seaborn as sns
import pandas as pd
data = pd.read_csv('C:\\Users\\HP\\Sravani\\synthetic_credit_card_transactions.csv') 
cardtype_counts = data['Card_Type'].value_counts().reset_index()
cardtype_counts.columns = ['Card_Type', 'Count']
top_events = cardtype_counts.head(20)

plt.figure(figsize=(14, 8))
sns.barplot(x='Count', y='Card_Type', data=top_events, hue='Card_Type', palette='magma', legend=False)
plt.title('Top 20 Card_Types used by Number of Customers')
plt.xlabel('Number of cards')
plt.ylabel('Card_Type')
plt.savefig("C:\\Users\\HP\\Downloads\\three.png") #to save pie chart in desired location
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Load data
data = pd.read_csv('C:\\Users\\HP\\Sravani\\synthetic_credit_card_transactions.csv')

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Encode the categorical columns as numbers
data['Card_Type'] = label_encoder.fit_transform(data['Card_Type'])
data['Merchant_Category'] = label_encoder.fit_transform(data['Merchant_Category'])
data['Location'] = label_encoder.fit_transform(data['Location'])

# Now, select only the numerical columns for correlation
numerical_data = data.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
plt.figure(figsize=(10, 8))
correlation = numerical_data.corr()

# Plot the heatmap
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('C:\\Users\\HP\\Sravani\\synthetic_credit_card_transactions.csv') 
# Count the occurrences of each category for the top countries
top_countries_counts = data[['Transaction_Type', 'Merchant_Category', 'Card_Type']].apply(pd.Series.value_counts)

# Create a stacked bar chart of the counts
plt.figure(figsize=(14, 8))
top_countries_counts.plot(kind='bar', stacked=True, color=['gold', 'silver', '#cd7f32'], ax=plt.gca())

# Add labels and title
plt.title('Distribution for Top 30 Countries')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.savefig("C:\\Users\\HP\\Downloads\\four.png") #to save pie chart in desired location
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('C:\\Users\\HP\\Sravani\\synthetic_credit_card_transactions.csv') 

# Get the top 10 countries with the highest number of transactions
top_countries = data['Location'].value_counts().head(10)

# Create a bar plot
plt.figure(figsize=(14, 8))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='magma')

# Add titles and labels
plt.title('Number of Transactions Occurred in Every Country')
plt.xlabel('Number of Transactions')
plt.ylabel('Top 10 Countries')

# Optionally save the plot
plt.savefig("C:\\Users\\HP\\Downloads\\five.png")

# Show the plot
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3876\4231486187.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette='magma')
